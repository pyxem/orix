# %% [markdown]
# This notebook is part of the *orix* documentation https://orix.rtfd.io. Links to the documentation won’t work from the notebook.

# %% [markdown]
# # Fundamental sectors in the stereographic projection
#
# | Hermann-Mauguin | Schoenflies |
# | --------------- | ----------- |
# |       *1*       |     *C1*    |
# |       *2*       |     *C2*    |
# |      *222*      |     *D2*    |
# |       *4*       |     *C4*    |
# |      *422*      |     *D4*    |
# |       *3*       |     *C3*    |
# |       *32*      |     *D3*    |
# |       *6*       |     *C6*    |
# |      *622*      |     *D6*    |
# |       *23*      |     *T*     |
# |      *432*      |     *O*     |

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
from orix.quaternion import symmetry
from orix import plot


# We'll want our plots to look a bit larger than the default size
new_params = {
    "figure.facecolor": "w",
    "lines.markersize": 10,
    "font.size": 20,
    "axes.grid": True,
}
plt.rcParams.update(new_params)

# %%
pg = [
    symmetry.C1,
    symmetry.C2,
    symmetry.D2,
    symmetry.C4,
    symmetry.D4,
    symmetry.C3,
    symmetry.D3,
    symmetry.C6,
    symmetry.D6,
    symmetry.T,
    symmetry.O,
]

fig, axes = plt.subplots(
    ncols=4, nrows=3, subplot_kw=dict(projection="stereographic"), figsize=(20, 13)
)
axes = axes.ravel()
for i in range(len(pg)):
    fs = pg[i].fundamental_sector
    print(pg[i].name, fs)
    axes[i].set_title(pg[i].name)
    axes[i].scatter(fs.vertices, c="g")
    axes[i].plot(fs.edges, color="r")
    axes[i].scatter(fs.center, c="b")
axes[-1].set_visible(False)
# Out:
# 1 FundamentalSector (0,)
# []
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/kode/orix/orix/plot/stereographic_plot.py in _pretransform_input(self, values, sort)
#     554                 if sort:
# --> 555                     order = _order_in_hemisphere(v.polar.data, hemisphere=hemisphere)
#     556                     v = v[order]
#
# ~/kode/orix/orix/plot/stereographic_plot.py in _order_in_hemisphere(polar, hemisphere)
#     631     order = np.arange(visible.size)
# --> 632     shift = func(polar_visible)
#     633     if polar_visible.size != 0 and shift != 0:
#
# <__array_function__ internals> in argmax(*args, **kwargs)
#
# ~/miniconda3/envs/orix-dev/lib/python3.9/site-packages/numpy/core/fromnumeric.py in argmax(a, axis, out)
#    1192     """
# -> 1193     return _wrapfunc(a, 'argmax', axis=axis, out=out)
#    1194
#
# ~/miniconda3/envs/orix-dev/lib/python3.9/site-packages/numpy/core/fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      57     try:
# ---> 58         return bound(*args, **kwds)
#      59     except TypeError:
#
# ValueError: attempt to get argmax of an empty sequence
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_54335/3521282123.py in <module>
#      22     axes[i].set_title(pg[i].name)
#      23     axes[i].scatter(fs.vertices, c="g")
# ---> 24     axes[i].plot(fs.edges, color="r")
#      25     axes[i].scatter(fs.center, c="b")
#      26 axes[-1].set_visible(False)
#
# ~/kode/orix/orix/plot/stereographic_plot.py in plot(self, *args, **kwargs)
#     108     def plot(self, *args, **kwargs):
#     109         new_kwargs = dict(clip_on=True, linewidth=2, color="k", linestyle="-")
# --> 110         out = self._prepare_to_call_inherited_method(args, kwargs, new_kwargs, sort=True)
#     111         if out is None:
#     112             return
#
# ~/kode/orix/orix/plot/stereographic_plot.py in _prepare_to_call_inherited_method(self, args, kwargs, new_kwargs, sort)
#     514                 updated_kwargs.setdefault(k, v)
#     515
# --> 516         x, y, visible = self._pretransform_input(args, sort=sort)
#     517
#     518         # Exclude vectors not visible in this hemisphere
#
# ~/kode/orix/orix/plot/stereographic_plot.py in _pretransform_input(self, values, sort)
#     557                 x, y = self._projection.vector2xy(v)
#     558             except (ValueError, AttributeError):
# --> 559                 raise ValueError(
#     560                     "Accepts only one (Vector3d) or two (azimuth, polar) input "
#     561                     "arguments"
#
# ValueError: Accepts only one (Vector3d) or two (azimuth, polar) input arguments

# %%
fig, axes = plt.subplots(
    ncols=4, nrows=3, subplot_kw=dict(projection="stereographic"), figsize=(20, 13)
)
axes = axes.ravel()
for i in range(len(pg)):
    fs = pg[i].fundamental_sector
    axes[i].plot(fs.edges, color="r")
    axes[i].restrict_to_sector(fs)
axes[-1].set_visible(False)
